# %%
import geopandas as gpd
india_file = "/data/examples/ncl_india/india.shp"
india = gpd.read_file(india_file)
print(india)
# Out:
#    scalerank       featurecla  labelrank sovereignt sov_a3  adm0_dif  level  \
# 0          0  Admin-0 country        2.0      India    IND       0.0    2.0
#
#                 type  admin adm0_a3  ...  continent region_un      subregion  \
# 0  Sovereign country  India     IND  ...       Asia      Asia  Southern Asia
#
#     region_wb name_len long_len  abbrev_len  tiny homepart  \
# 0  South Asia      5.0      5.0         5.0 -99.0      1.0
#
#                                             geometry
# 0  POLYGON ((74.79257 37.01516, 74.82430 36.99413...
#
# [1 rows x 64 columns]

# %%
india.plot(figsize=(10, 10))
# Out:
# <AxesSubplot:>
